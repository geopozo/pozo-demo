# %% [markdown]
# # Pozo Demo
# ### Step 1: Import Packages

# %%
# pip install pozo
import lasio # Lasio reads well las files!
import pozo # Pozo visualizes them!

# %% [markdown]
# ### Step 2: Import and Verify Data

# %%
las = lasio.read("https://raw.githubusercontent.com/geopozo/pozo-demo/main/SALADIN.LAS")

pozo.units.check_las(las)
# Out:
# <div id=""><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mnemonic</th>
#       <th>las unit</th>
#       <th>pozo mapping</th>
#       <th>confidence</th>
#       <th>parsed</th>
#       <th>description</th>
#       <th>min</th>
#       <th>med</th>
#       <th>max</th>
#       <th>#NaN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>DEPT:1</td>
#       <td>M</td>
#       <td>meter</td>
#       <td>HIGH</td>
#       <td>meter</td>
#       <td>Depth</td>
#       <td>0.152400</td>
#       <td>916.152600</td>
#       <td>1832.152800</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>DEPT:2</td>
#       <td>M</td>
#       <td>meter</td>
#       <td>HIGH</td>
#       <td>meter</td>
#       <td>Measured Depth</td>
#       <td>0.152390</td>
#       <td>915.847800</td>
#       <td>1831.543000</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CALI</td>
#       <td>CM</td>
#       <td>centimeter</td>
#       <td>HIGH</td>
#       <td>centimeter</td>
#       <td>Caliper Log</td>
#       <td>8.308773</td>
#       <td>12.111990</td>
#       <td>18.687780</td>
#       <td>2162</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CGR</td>
#       <td>GAPI</td>
#       <td>gAPI</td>
#       <td>HIGH</td>
#       <td>gamma_API_unit</td>
#       <td>Computed Gamma-Ray (Thorium + Potassium)</td>
#       <td>35.492740</td>
#       <td>67.905470</td>
#       <td>134.135700</td>
#       <td>11343</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>DRHO</td>
#       <td>G/C3</td>
#       <td>gram / centimeter ** 3</td>
#       <td>HIGH</td>
#       <td>gram / centimeter ** 3</td>
#       <td>Density Log Correction</td>
#       <td>-0.023430</td>
#       <td>0.006997</td>
#       <td>0.199013</td>
#       <td>7243</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>DT</td>
#       <td>US/F</td>
#       <td>microsecond / foot</td>
#       <td>HIGH</td>
#       <td>microsecond / foot</td>
#       <td>Delta T</td>
#       <td>66.927280</td>
#       <td>114.407450</td>
#       <td>167.895000</td>
#       <td>2048</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>GR</td>
#       <td>GAPI</td>
#       <td>gAPI</td>
#       <td>HIGH</td>
#       <td>gamma_API_unit</td>
#       <td>Gamma-Ray Log</td>
#       <td>19.713210</td>
#       <td>90.656420</td>
#       <td>200.234900</td>
#       <td>295</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>ILD</td>
#       <td>OHMM</td>
#       <td>ohm * meter</td>
#       <td>HIGH</td>
#       <td>meter * ohm</td>
#       <td>Induction Deep Resistivity</td>
#       <td>0.332287</td>
#       <td>1.118745</td>
#       <td>1962.302000</td>
#       <td>1997</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ILM</td>
#       <td>OHMM</td>
#       <td>ohm * meter</td>
#       <td>HIGH</td>
#       <td>meter * ohm</td>
#       <td>Medium Induction Log</td>
#       <td>0.361660</td>
#       <td>1.087331</td>
#       <td>318.747500</td>
#       <td>1996</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>LLD</td>
#       <td>OHMM</td>
#       <td>ohm * meter</td>
#       <td>HIGH</td>
#       <td>meter * ohm</td>
#       <td>Laterolog Deep Resistivity</td>
#       <td>0.507519</td>
#       <td>2.110815</td>
#       <td>540.812900</td>
#       <td>7193</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>LLS</td>
#       <td>OHMM</td>
#       <td>ohm * meter</td>
#       <td>HIGH</td>
#       <td>meter * ohm</td>
#       <td>Shallow Laterolog</td>
#       <td>0.372947</td>
#       <td>1.938230</td>
#       <td>450.769000</td>
#       <td>7191</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>MSFL</td>
#       <td>OHMM</td>
#       <td>ohm * meter</td>
#       <td>HIGH</td>
#       <td>meter * ohm</td>
#       <td>Micro Spherically Focused Log</td>
#       <td>0.188423</td>
#       <td>1.504863</td>
#       <td>186.605300</td>
#       <td>7226</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>NPHI</td>
#       <td>PU</td>
#       <td>pu</td>
#       <td style="color:#B95000">decide by range - MEDIUM</td>
#       <td>porosity_unit</td>
#       <td>Neutron Log Porosity</td>
#       <td>7.626792</td>
#       <td>24.326625</td>
#       <td>51.502840</td>
#       <td>7284</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>PEF</td>
#       <td></td>
#       <td>percent</td>
#       <td style="color:red">decide by range, verify - LOW</td>
#       <td>percent</td>
#       <td>Photoelectric Factor</td>
#       <td>0.825900</td>
#       <td>2.574829</td>
#       <td>7.288238</td>
#       <td>7252</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>POTA</td>
#       <td></td>
#       <td>percent</td>
#       <td style="color:red">decide by range, verify - LOW</td>
#       <td>percent</td>
#       <td>Potassium Concentration</td>
#       <td>0.015617</td>
#       <td>0.024095</td>
#       <td>0.049397</td>
#       <td>11342</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>RHOB</td>
#       <td>G/C3</td>
#       <td>gram / centimeter ** 3</td>
#       <td>HIGH</td>
#       <td>gram / centimeter ** 3</td>
#       <td>Compensated Formation Density Log</td>
#       <td>1.350388</td>
#       <td>2.383768</td>
#       <td>2.767407</td>
#       <td>7259</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>SFL</td>
#       <td>OHMM</td>
#       <td>ohm * meter</td>
#       <td>HIGH</td>
#       <td>meter * ohm</td>
#       <td>SFL Resistivity Averaged over 2.5 Ft</td>
#       <td>0.372945</td>
#       <td>1.151833</td>
#       <td>1001.701000</td>
#       <td>2008</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>SGR</td>
#       <td>GAPI</td>
#       <td>gAPI</td>
#       <td>HIGH</td>
#       <td>gamma_API_unit</td>
#       <td>Spectral Gamma-Ray</td>
#       <td>35.138430</td>
#       <td>106.741000</td>
#       <td>176.150700</td>
#       <td>7285</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>SP</td>
#       <td>MV</td>
#       <td>millivolt</td>
#       <td>HIGH</td>
#       <td>millivolt</td>
#       <td>Spontaneous Potential Log</td>
#       <td>28.591510</td>
#       <td>43.936930</td>
#       <td>70.276180</td>
#       <td>1986</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>THOR</td>
#       <td></td>
#       <td>percent</td>
#       <td style="color:red">decide by range, verify - LOW</td>
#       <td>percent</td>
#       <td>Thorium</td>
#       <td>1.944721</td>
#       <td>6.116129</td>
#       <td>19.688490</td>
#       <td>11344</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>URAN</td>
#       <td></td>
#       <td>percent</td>
#       <td style="color:red">decide by range, verify - LOW</td>
#       <td>percent</td>
#       <td>Uranium</td>
#       <td>-0.234460</td>
#       <td>0.126292</td>
#       <td>3.758161</td>
#       <td>11337</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
graph1 = pozo.Graph(las, unit_map={"THOR":"ppm", "POTA":"fraction"})
graph1.summarize_curves(height=600)
# Out:
# FigureWidget({
#     'data': [{'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'DEPT',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'cfe2e299-82ab-4173-a6ef-98109294a089',
#               'x': {'bdata': ('/Yf029eBwz/9h/Tb14HTP/vL7snDQt' ... 'xaZJ+cQKyL22gAoJxAUWuad5ygnEA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('/Yf029eBwz/9h/Tb14HTP/vL7snDQt' ... 'xaZJ+cQKyL22gAoJxAUWuad5ygnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'DEPT',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2a322497-2dfb-4462-80c7-a5fc80f05019',
#               'x': {'bdata': ('G46dpoWBwz931agsr4HTP3UZoxqbQt' ... 'FFtvOcnEDy0k1ikJ2cQOkmMQgsnpxA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('/Yf029eBwz/9h/Tb14HTP/vL7snDQt' ... 'wcWmSfnECsi9toAKCcQFFrmnecoJxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CALI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b8d5e8e8-f508-4be6-8794-57b674e56254',
#               'x': {'bdata': ('uK8D54x4KEBsPq4NFXMoQMu5FFeVTS' ... 'NdEyFAOxqH+l0QIUDS5GIMrAshQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('LGUZ4ljjckC94xQdyeVyQE5iEFg56H' ... 'iVUpxA1XjpJjFTnEB5WKg1zVOcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '827bf844-e33d-4aa1-9c06-e7235cdd0d28',
#               'x': {'bdata': ('6Ugu/yGjUkCmft5UpIZSQNqPFJFhh1' ... '8LtSZOQECH+fIC8FBAxF+TNeoPU0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x4',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'DRHO',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b33b164f-6de4-4990-a5eb-a275846a8d0e',
#               'x': {'bdata': ('T/NExlnHhz+VNDW/UHaRP+zmmOJgJY' ... 'EwnkFDlz84zyIlh5mXPyqtvyUA/5Q/'),
#                     'dtype': 'f8'},
#               'xaxis': 'x5',
#               'y': {'bdata': ('JLn8h/QNkUDImLuWkA6RQGx4eqUsD5' ... 'm3rwNunEC0yHa+n26cQFioNc07b5xA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'DT',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b1e2a50d-d078-4aaa-95ff-426064615562',
#               'x': {'bdata': ('9pfdk4fdXEBN845TdKhdQKmkTkAT2V' ... 'hVOFRAVDpY/+e+VEBjnL8JhT5VQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x6',
#               'y': {'bdata': ('veMUHcnlckBOYhBYOehyQN/gC5Op6n' ... 'eYeZxA5WGh1jR6nECJQWDl0HqcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'GR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '000d66c8-0f13-4f65-962e-b11033f2859e',
#               'x': {'bdata': ('Q+c1dolyOEBCW86luLI4QDAqqRPQxD' ... 'tRuB7TYkB8YTJVMJhiQFXBqKROCmJA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x7',
#               'y': {'bdata': ('i2zn+6kxPECbVZ+rrVg8QKs+V1uxfz' ... 'JVMCpenEAGEhQ/xl6cQKrx0k1iX5xA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '078040d7-9dc7-4015-94fe-8198d30c9c0d',
#               'x': {'bdata': ('b+ahAJs93T8WmF8XjxzdPx+duvJZHt' ... 'ykOgpAkKD4MeZuCkB+x/DYz0IKQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x8',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... 'kTmJxA+Q/pt6+YnECe76fGS5mcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILM',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '72b29da1-b23a-4121-95d5-defecc0cbb20',
#               'x': {'bdata': ('iudsAaE14T//DvvzIzThP8/abReaq+' ... 'RyLzDLCUCamC7E6m8JQIXNABdkiwlA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... '+nxkuZnEBCz2bV55mcQOauJeSDmpxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '107e55e9-e76d-47ef-bd9c-ad37e3a10f01',
#               'x': {'bdata': ('Y/IGmPnO9T8WwmosYS36P11r71NV6P' ... 'XU6gdAxqhr7X3KB0Dg10gShGsHQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x10',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'kmkJxAorQ3+MKQnEBGlPYGX5GcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLS',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6875d937-e281-4148-b233-28fa9044b7fa',
#               'x': {'bdata': ('xr5k48GW8z9bzxCOWXb2PypWDcLc7v' ... 'Mh/2wHQPG9v0F7NQdAdVYL7DHRBkA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x11',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'f4wpCcQEaU9gZfkZxA63O1FfuRnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'MSFL',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '603f79cb-f45b-432c-9984-9913b09f4aef',
#               'x': {'bdata': ('PIcyVMXU8D8P1v85zJfnP4KWCRqOQs' ... 'UIOQtAyvrNxHQBBEADJnDrbn4CQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x12',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'n8eJxAQYLix5h5nEDlYaHWNHqcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'NPHI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b762962d-464b-47d9-a689-201b5722ead0',
#               'x': {'bdata': ('EAaeew9bQUBIbeLkfmNDQD7t8NdkpU' ... 'ms+uQ0QGFPO/w1GTVAYOXQItuRNUA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x13',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'PEF',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'da97fd20-1e11-4d9b-b1df-53e3dc422313',
#               'x': {'bdata': ('6GhVSzqK+T8W2jnNAm30P8lXAimxq/' ... 'Bh2jdXBkDBVgkWh1MGQMzR4/c2nQZA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x14',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'vAOSNpnECSy39Iv2mcQDarPldbapxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'POTA',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b044722e-64c8-45a4-b138-f72da50ce82d',
#               'x': {'bdata': ('E+UchqC0mT+GX0WhwJaaP06QInw5/Z' ... 'I1FZs/J7yp7cs+nD+jw42lWeqaPw=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x15',
#               'y': {'bdata': ('RGlv8IXykEDpSC7/IfOQQI0o7Q2+85' ... '84j5JARrbz/dSPkkDqlbIMcZCSQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'RHOB',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7b3416e9-2a1a-43b7-8286-a7bebda0d646',
#               'x': {'bdata': ('ebKbGf3o/j8a3xeXqvT6P+3zGOWZV/' ... 'cqPwRAXkvIBz07BEAqjZjZ5zEEQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x16',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'LeZJxAFK5H4XplnEC5jQbwFmacQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'SFL',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '20263138-f29f-459f-b848-01ca4fff4982',
#               'x': {'bdata': ('v1r/+Fy34z9tyaoIN9nkP3imhuxyQO' ... 'LMJVX7B0BNaf0tAfgHQHh7EALyBQhA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x17',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... 'LyQc+TnEB88rBQa5ScQCDSb18HlZxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'SGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '22b364d3-0972-40c9-8400-1084123b2e44',
#               'x': {'bdata': ('QDBHj9/5UkBnLJrOTvZSQLosJjYf+1' ... '+nxkuHW0B/arx0k+xbQHRGlPYG11xA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x18',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'gbnl44nEA+6Nms+jicQOPHmLuWOZxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'SP',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'cdd39c05-8397-423e-884b-dd4dd2b87a83',
#               'x': {'bdata': ('Y5y/CYVQRUDQJ/Ik6QpGQNEi2/l+nk' ... '3kmwVJQE0tW+uL/EhARkJbzqXsSEA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x19',
#               'y': {'bdata': ('veMUHcnlckBOYhBYOehyQN/gC5Op6n' ... 'xaZJ+cQKyL22gAoJxAUWuad5ygnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'THOR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c4990834-5492-40dc-990b-11e323659c3c',
#               'x': {'bdata': ('/MIrSZ5zIUDf+xu0V0cgQLzNGyeFqR' ... 'pGrwZIFUDrckpATHIXQJqUgm4v+R5A'),
#                     'dtype': 'f8'},
#               'xaxis': 'x20',
#               'y': {'bdata': ('RGlv8IXykEDpSC7/IfOQQI0o7Q2+85' ... 'e30QCOkkD99nXgnI6SQKHWNO84j5JA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'URAN',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0bbc6ece-4d06-4e60-87fc-7364f0987a90',
#               'x': {'bdata': ('4PWZsz7lrD/hfVUuVP61P/5fdeRIZ8' ... 'mljkTSP8gJE0azMvY/EyhiEcNO/z8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x21',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'AqqZGSQNc07zhFkpJAexSuR+GSkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y2',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '00889f95-6403-40cc-9e85-8caca3087b1c',
#               'x': {'bdata': ('/Yf029eBwz/9h/Tb14HTP/vL7snDQt' ... 'xaZJ+cQKyL22gAoJxAUWuad5ygnEA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'yaxis': 'y2'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y3',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': 'a6c22aa4-805d-447a-8274-0089a26bb535',
#               'x': {'bdata': ('G46dpoWBwz931agsr4HTP3UZoxqbQt' ... 'W285ycQPLSTWKQnZxA6SYxCCyenEA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'yaxis': 'y3'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y4',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '5c395b25-b20a-4ff2-b627-e635c7bfb991',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'yaxis': 'y4'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y5',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '5e22f3a6-1fbd-4872-b48c-bab871423832',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x4',
#               'yaxis': 'y5'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y6',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '0f311446-f3f6-4f16-8478-a49b845cf6d7',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x5',
#               'yaxis': 'y6'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y7',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '5c940798-e11a-421d-babc-5b1b80fe6f95',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x6',
#               'yaxis': 'y7'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y8',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': 'd4ea51ca-3c49-4566-b359-25dc3b13c0e6',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x7',
#               'yaxis': 'y8'},
#              {'boxpoints': 'suspectedoutliers',
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'points',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'pointpos': 0,
#               'showlegend': False,
#               'type': 'box',
#               'uid': 'ad0934d2-5f18-4687-86ef-644ed3362655',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x8',
#               'yaxis': 'y9'},
#              {'boxpoints': 'suspectedoutliers',
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'points',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'pointpos': 0,
#               'showlegend': False,
#               'type': 'box',
#               'uid': 'de535411-0212-4f68-b893-65a72540b36c',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'yaxis': 'y10'},
#              {'boxpoints': 'suspectedoutliers',
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'points',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'pointpos': 0,
#               'showlegend': False,
#               'type': 'box',
#               'uid': '92f3e257-a4ae-4b19-9406-07a71ecb2033',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x10',
#               'yaxis': 'y11'},
#              {'boxpoints': 'suspectedoutliers',
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'points',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'pointpos': 0,
#               'showlegend': False,
#               'type': 'box',
#               'uid': '62cfff1a-ea1b-4285-9f71-08c717316005',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x11',
#               'yaxis': 'y12'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y13',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': 'c2236e5e-5833-40a6-a717-818a3cefe47d',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x12',
#               'yaxis': 'y13'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y14',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': 'e01e765b-806a-4d52-8745-7eabe6c3e56f',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x13',
#               'yaxis': 'y14'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y15',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '0bedce2a-6159-40ae-ac55-b8a7ce035db3',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x14',
#               'yaxis': 'y15'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y16',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '46f27ae4-a03d-4c49-a7b9-5ecde9cfa6f8',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x15',
#               'yaxis': 'y16'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y17',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': 'd9a5ff84-eb3f-433d-9f2f-0ea60878c454',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x16',
#               'yaxis': 'y17'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y18',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '6e4e74fa-0c50-4d51-8626-11dc95bcf6d8',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x17',
#               'yaxis': 'y18'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y19',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '5dddb371-aadf-42c4-bf61-21eab389e431',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x18',
#               'yaxis': 'y19'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y20',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '11919a92-b238-4169-b8f4-505970693673',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... '3kmwVJQE0tW+uL/EhARkJbzqXsSEA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x19',
#               'yaxis': 'y20'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y21',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': 'b98cf3d9-fc2b-4fa5-b327-ade126ee15aa',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x20',
#               'yaxis': 'y21'},
#              {'box': {'visible': False},
#               'fillcolor': 'rgba(0,0,0, .3)',
#               'hoveron': 'kde',
#               'hovertemplate': '%{x}',
#               'line': {'color': 'black'},
#               'name': '',
#               'opacity': 0.7,
#               'points': 'suspectedoutliers',
#               'scalegroup': 'y22',
#               'showlegend': False,
#               'type': 'violin',
#               'uid': '5c48976b-177a-4020-87af-697dfbcf3829',
#               'x': {'bdata': ('AAAAAAAA+H8AAAAAAAD4fwAAAAAAAP' ... 'AAAAD4fwAAAAAAAPh/AAAAAAAA+H8='),
#                     'dtype': 'f8'},
#               'xaxis': 'x21',
#               'yaxis': 'y22'}],
#     'layout': {'height': 600,
#                'legend': {'xanchor': 'left', 'y': 1, 'yanchor': 'top'},
#                'margin': {'b': 5, 'l': 15, 'r': 15, 't': 5},
#                'paper_bgcolor': '#FFFFFF',
#                'plot_bgcolor': '#FFFFFF',
#                'showlegend': True,
#                'template': '...',
#                'width': 6604,
#                'xaxis': {'domain': [0.0006056935190793458, 0.04603270745003028],
#                          'gridcolor': '#f0f0f0',
#                          'linecolor': '#000000',
#                          'linewidth': 2,
#                          'nticks': 0,
#                          'position': 1,
#                          'range': [None, None],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'top',
#                          'tickangle': 55,
#                          'tickcolor': '#000000',
#                          'tickfont': {'color': '#000000'},
#                          'ticklen': 6,
#                          'tickmode': 'auto',
#                          'ticks': 'outside',
#                          'tickwidth': 1,
#                          'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'DEPT (m)'},
#                          'type': 'linear',
#                          'zeroline': False},
#                'xaxis10': {'domain': [0.4298909751665657, 0.47531798909751666],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [-0.6989700043360187, 3.301029995663981],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'LLD (m*Ω)'},
#                            'type': 'log',
#                            'zeroline': False},
#                'xaxis11': {'domain': [0.4775893397940642, 0.5230163537250151],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [-0.6989700043360187, 3.301029995663981],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'LLS (m*Ω)'},
#                            'type': 'log',
#                            'zeroline': False},
#                'xaxis12': {'domain': [0.5252877044215627, 0.5707147183525136],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'MSFL (m*Ω)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis13': {'domain': [0.5729860690490611, 0.6184130829800121],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [45.0, -15.0],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'NPHI (pu)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis14': {'domain': [0.6206844336765597, 0.6661114476075106],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'PEF (%)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis15': {'domain': [0.6683827983040581, 0.7138098122350091],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'POTA (fraction)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis16': {'domain': [0.7160811629315567, 0.7615081768625076],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [1.95, 2.95],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'RHOB (g/cm^3)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis17': {'domain': [0.7637795275590551, 0.809206541490006],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'SFL (m*Ω)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis18': {'domain': [0.8114778921865536, 0.8569049061175046],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'SGR (gAPI)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis19': {'domain': [0.8591762568140521, 0.904603270745003],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'SP (mV)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis2': {'domain': [0.04830405814657783, 0.09373107207752877],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [None, None],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'DEPT (m)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis20': {'domain': [0.9068746214415506, 0.9523016353725016],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'THOR (ppm)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis21': {'domain': [0.9545729860690491, 1.0],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#000000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 1,
#                            'range': [None, None],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#000000',
#                            'tickfont': {'color': '#000000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'URAN (%)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis3': {'domain': [0.09600242277407632, 0.14142943670502725],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [0.0, 40.64],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CALI (cm)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis4': {'domain': [0.1437007874015748, 0.18912780133252574],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [0, 150.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CGR (gAPI)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis5': {'domain': [0.1913991520290733, 0.23682616596002423],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [None, None],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'DRHO (g/cm^3)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis6': {'domain': [0.23909751665657178, 0.2845245305875227],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [30, 200],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'DT (µs/ft)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis7': {'domain': [0.28679588128407024, 0.3322228952150212],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [0, 150.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'GR (gAPI)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis8': {'domain': [0.33449424591156873, 0.3799212598425197],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'ILD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis9': {'domain': [0.3821926105390672, 0.42761962447001817],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 1,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'ILM (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'yaxis': {'domain': [0.2, 1],
#                          'gridcolor': '#f0f0f0',
#                          'maxallowed': np.float64(1832.1528),
#                          'minallowed': np.float64(0.1524),
#                          'position': 0,
#                          'range': [1832.1528, 0.1524],
#                          'showgrid': True,
#                          'showline': False,
#                          'visible': True,
#                          'zeroline': False},
#                'yaxis10': {'anchor': 'x9', 'domain': [0, 0.2]},
#                'yaxis11': {'anchor': 'x10', 'domain': [0, 0.2]},
#                'yaxis12': {'anchor': 'x11', 'domain': [0, 0.2]},
#                'yaxis13': {'anchor': 'x12', 'domain': [0, 0.2]},
#                'yaxis14': {'anchor': 'x13', 'domain': [0, 0.2]},
#                'yaxis15': {'anchor': 'x14', 'domain': [0, 0.2]},
#                'yaxis16': {'anchor': 'x15', 'domain': [0, 0.2]},
#                'yaxis17': {'anchor': 'x16', 'domain': [0, 0.2]},
#                'yaxis18': {'anchor': 'x17', 'domain': [0, 0.2]},
#                'yaxis19': {'anchor': 'x18', 'domain': [0, 0.2]},
#                'yaxis2': {'anchor': 'x', 'domain': [0, 0.2]},
#                'yaxis20': {'anchor': 'x19', 'domain': [0, 0.2]},
#                'yaxis21': {'anchor': 'x20', 'domain': [0, 0.2]},
#                'yaxis22': {'anchor': 'x21', 'domain': [0, 0.2]},
#                'yaxis3': {'anchor': 'x2', 'domain': [0, 0.2]},
#                'yaxis4': {'anchor': 'x3', 'domain': [0, 0.2]},
#                'yaxis5': {'anchor': 'x4', 'domain': [0, 0.2]},
#                'yaxis6': {'anchor': 'x5', 'domain': [0, 0.2]},
#                'yaxis7': {'anchor': 'x6', 'domain': [0, 0.2]},
#                'yaxis8': {'anchor': 'x7', 'domain': [0, 0.2]},
#                'yaxis9': {'anchor': 'x8', 'domain': [0, 0.2]}}
# })

# %% [markdown]
# ### Step 3: Customize The Graph

# %%
include = ["CALI", "CGR", "LLS", "ILM", "ILD", "LLD", "NPHI", "RHOB", "GR"]
graph2 = pozo.Graph(las,  yaxis_name="DEPT:1", include=include) 

# Combining CGR CALI
graph2.combine_tracks("CGR", "CALI")

# Combining Conductivities
graph2.combine_tracks("LLD","ILD","ILM","LLS") 

# Combining NPHI RHOB
graph2.combine_tracks("RHOB", "NPHI")


graph2.set_theme("cangrejo")
graph2.get_theme().set_fallback("track_width", 150)

# This could have a better interface
graph2.note_dict['Mardie Greensand'] = pozo.Note(1105, line=dict(color="#00FFFF"), text='Mardie Greensand')
graph2.note_dict['Barrow Group'] = pozo.Note((1115, 1125), line=dict(color="green"), text='Barrow Group')

graph2.render(depth_position=1, depth=[1080, 1180])
# Out:
# xpFigureWidget({
#     'data': [{'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c3e7969b-f7b1-453f-a563-aa7440c89930',
#               'x': {'bdata': ('6Ugu/yGjUkCmft5UpIZSQNqPFJFhh1' ... '8LtSZOQECH+fIC8FBAxF+TNeoPU0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CALI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2cde50aa-5a77-4174-ad26-b2eb209b314f',
#               'x': {'bdata': ('uK8D54x4KEBsPq4NFXMoQMu5FFeVTS' ... 'NdEyFAOxqH+l0QIUDS5GIMrAshQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('LGUZ4ljjckC94xQdyeVyQE5iEFg56H' ... 'iVUpxA1XjpJjFTnEB5WKg1zVOcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '68c02c1d-9b5a-42e0-ac09-e86fcaf479ac',
#               'x': {'bdata': ('Y/IGmPnO9T8WwmosYS36P11r71NV6P' ... 'XU6gdAxqhr7X3KB0Dg10gShGsHQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'kmkJxAorQ3+MKQnEBGlPYGX5GcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8faa0f1b-f619-424a-b353-b4229f980290',
#               'x': {'bdata': ('b+ahAJs93T8WmF8XjxzdPx+duvJZHt' ... 'ykOgpAkKD4MeZuCkB+x/DYz0IKQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x4',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... 'kTmJxA+Q/pt6+YnECe76fGS5mcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#0000ff', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILM',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '324970c6-09cc-446b-af69-ebc326f55075',
#               'x': {'bdata': ('iudsAaE14T//DvvzIzThP8/abReaq+' ... 'RyLzDLCUCamC7E6m8JQIXNABdkiwlA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x5',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... '+nxkuZnEBCz2bV55mcQOauJeSDmpxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#808080', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLS',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e938d1fc-9426-44d6-8347-9adb5ae4857d',
#               'x': {'bdata': ('xr5k48GW8z9bzxCOWXb2PypWDcLc7v' ... 'Mh/2wHQPG9v0F7NQdAdVYL7DHRBkA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x6',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'f4wpCcQEaU9gZfkZxA63O1FfuRnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'RHOB',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd8f2ed82-76ad-4ae4-9453-55d5b58b2cf1',
#               'x': {'bdata': ('ebKbGf3o/j8a3xeXqvT6P+3zGOWZV/' ... 'cqPwRAXkvIBz07BEAqjZjZ5zEEQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x7',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'LeZJxAFK5H4XplnEC5jQbwFmacQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008080', 'width': 1},
#               'mode': 'lines',
#               'name': 'NPHI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9bc77178-3665-4e82-8290-d22dfe3e62ec',
#               'x': {'bdata': ('EAaeew9bQUBIbeLkfmNDQD7t8NdkpU' ... 'ms+uQ0QGFPO/w1GTVAYOXQItuRNUA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x8',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'GR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b55166b9-e35e-4e38-a1cf-a97616e00276',
#               'x': {'bdata': ('Q+c1dolyOEBCW86luLI4QDAqqRPQxD' ... 'tRuB7TYkB8YTJVMJhiQFXBqKROCmJA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('i2zn+6kxPECbVZ+rrVg8QKs+V1uxfz' ... 'JVMCpenEAGEhQ/xl6cQKrx0k1iX5xA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Mardie Greensand',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1105,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Barrow Group',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1115,
#                                 'yref': 'y',
#                                 'yshift': -5}],
#                'height': 900,
#                'legend': {'xanchor': 'left', 'y': 1, 'yanchor': 'top'},
#                'margin': {'b': 5, 'l': 15, 'r': 15, 't': 5},
#                'paper_bgcolor': '#FFFFFF',
#                'plot_bgcolor': '#FFFFFF',
#                'shapes': [{'line': {'color': '#00FFFF', 'dash': 'dot', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1105,
#                            'y1': 1105,
#                            'yref': 'y'},
#                           {'fillcolor': 'lightskyblue',
#                            'layer': 'above',
#                            'line': {'color': 'green', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1115,
#                            'y1': 1125,
#                            'yref': 'y'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 844,
#                'xaxis': {'domain': [0.004739336492890996, 0.18246445497630331],
#                          'gridcolor': '#f0f0f0',
#                          'linecolor': '#008000',
#                          'linewidth': 2,
#                          'nticks': 0,
#                          'position': 0.6444444444444444,
#                          'range': [0, 150.0],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'top',
#                          'tickangle': 55,
#                          'tickcolor': '#008000',
#                          'tickfont': {'color': '#008000'},
#                          'ticklen': 6,
#                          'tickmode': 'auto',
#                          'ticks': 'outside',
#                          'tickwidth': 1,
#                          'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'CGR (gAPI)'},
#                          'type': 'linear',
#                          'zeroline': False},
#                'xaxis2': {'anchor': 'free',
#                           'domain': [0.004739336492890996, 0.18246445497630331],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x',
#                           'position': 0.7333333333333334,
#                           'range': [0.0, 40.64],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CALI (cm)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis3': {'domain': [0.24170616113744076, 0.4194312796208531],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'LLD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis4': {'anchor': 'free',
#                           'domain': [0.24170616113744076, 0.4194312796208531],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.7333333333333334,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'ILD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis5': {'anchor': 'free',
#                           'domain': [0.24170616113744076, 0.4194312796208531],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#0000ff',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.8222222222222222,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#0000ff',
#                           'tickfont': {'color': '#0000ff'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#0000ff'}, 'standoff': 0, 'text': 'ILM (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis6': {'anchor': 'free',
#                           'domain': [0.24170616113744076, 0.4194312796208531],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#808080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.9111111111111111,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#808080',
#                           'tickfont': {'color': '#808080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#808080'}, 'standoff': 0, 'text': 'LLS (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis7': {'domain': [0.4372037914691943, 0.6149289099526066],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [1.95, 2.95],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'RHOB (g/cm^3)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis8': {'anchor': 'free',
#                           'domain': [0.4372037914691943, 0.6149289099526066],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#008080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x7',
#                           'position': 0.7333333333333334,
#                           'range': [45.0, -15.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#008080',
#                           'tickfont': {'color': '#008080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#008080'}, 'standoff': 0, 'text': 'NPHI (pu)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis9': {'domain': [0.6327014218009479, 0.8104265402843602],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#008000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [0, 150.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#008000',
#                           'tickfont': {'color': '#008000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'GR (gAPI)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'yaxis': {'domain': [0.011111111111111112, 0.6444444444444444],
#                          'gridcolor': '#f0f0f0',
#                          'maxallowed': np.float64(1832.1528),
#                          'minallowed': np.float64(0.1524),
#                          'position': 0.23696682464454977,
#                          'range': [1180, 1080],
#                          'showgrid': True,
#                          'showline': False,
#                          'visible': True,
#                          'zeroline': False}}
# })

# %%
striplog_track = pozo.Track(name="striplog")
striplog_track.set_theme({"force": True, "track_width": 30})
striplog_track.note_list.extend([
    pozo.Note((1080, 1090), fillcolor='darkslateblue', show_text=False, width=.4),
    pozo.Note((1090, 1110), fillcolor='darkseagreen', show_text=False, width=.5),
    pozo.Note((1110, 1115), fillcolor='darkslateblue', show_text=False, width=.7),
    pozo.Note((1115, 1155), fillcolor='goldenrod', show_text=False, width=.2),
    pozo.Note((1150, 1180), fillcolor='darkseagreen', show_text=False, width=.4),
])
graph2.replace_tracks(("striplog", striplog_track))
graph2.move_tracks(striplog_track, position=2)

graph2.render(depth_position=1, depth=[1080, 1180])
# Out:
# xpFigureWidget({
#     'data': [{'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7b10f320-50a5-414d-8ad9-0619da7efdc4',
#               'x': {'bdata': ('6Ugu/yGjUkCmft5UpIZSQNqPFJFhh1' ... '8LtSZOQECH+fIC8FBAxF+TNeoPU0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CALI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0434d798-9f75-4857-999d-99bcbf551111',
#               'x': {'bdata': ('uK8D54x4KEBsPq4NFXMoQMu5FFeVTS' ... 'NdEyFAOxqH+l0QIUDS5GIMrAshQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('LGUZ4ljjckC94xQdyeVyQE5iEFg56H' ... 'iVUpxA1XjpJjFTnEB5WKg1zVOcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e8a57259-f314-401c-8e1c-3ef09eb7c972',
#               'x': {'bdata': ('Y/IGmPnO9T8WwmosYS36P11r71NV6P' ... 'XU6gdAxqhr7X3KB0Dg10gShGsHQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'kmkJxAorQ3+MKQnEBGlPYGX5GcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '76898f85-8b45-4caa-a46c-2cd4753b3aaa',
#               'x': {'bdata': ('b+ahAJs93T8WmF8XjxzdPx+duvJZHt' ... 'ykOgpAkKD4MeZuCkB+x/DYz0IKQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x4',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... 'kTmJxA+Q/pt6+YnECe76fGS5mcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#0000ff', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILM',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'eaaa300e-8d39-4ee3-aa74-bb542b9fb2d7',
#               'x': {'bdata': ('iudsAaE14T//DvvzIzThP8/abReaq+' ... 'RyLzDLCUCamC7E6m8JQIXNABdkiwlA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x5',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... '+nxkuZnEBCz2bV55mcQOauJeSDmpxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#808080', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLS',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bb1c9cd8-403d-4689-a82c-b5832bb4f4a7',
#               'x': {'bdata': ('xr5k48GW8z9bzxCOWXb2PypWDcLc7v' ... 'Mh/2wHQPG9v0F7NQdAdVYL7DHRBkA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x6',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'f4wpCcQEaU9gZfkZxA63O1FfuRnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hoverinfo': 'skip',
#               'mode': 'markers',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '605d877a-e15d-4c94-b71b-ae23783614d4',
#               'x': [0],
#               'xaxis': 'x7',
#               'y': [0],
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'RHOB',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '59b4b342-2ea8-4851-bd4d-8dd089d63541',
#               'x': {'bdata': ('ebKbGf3o/j8a3xeXqvT6P+3zGOWZV/' ... 'cqPwRAXkvIBz07BEAqjZjZ5zEEQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x8',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'LeZJxAFK5H4XplnEC5jQbwFmacQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008080', 'width': 1},
#               'mode': 'lines',
#               'name': 'NPHI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4fd46146-c9e7-406d-ab96-68772ef51250',
#               'x': {'bdata': ('EAaeew9bQUBIbeLkfmNDQD7t8NdkpU' ... 'ms+uQ0QGFPO/w1GTVAYOXQItuRNUA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'GR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'de7e68c3-0c6b-41d6-9e46-e10d253dfbd5',
#               'x': {'bdata': ('Q+c1dolyOEBCW86luLI4QDAqqRPQxD' ... 'tRuB7TYkB8YTJVMJhiQFXBqKROCmJA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x10',
#               'y': {'bdata': ('i2zn+6kxPECbVZ+rrVg8QKs+V1uxfz' ... 'JVMCpenEAGEhQ/xl6cQKrx0k1iX5xA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Mardie Greensand',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1105,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Barrow Group',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1115,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1080,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1090,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1110,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1115,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1150,
#                                 'yref': 'y',
#                                 'yshift': -5}],
#                'height': 900,
#                'legend': {'xanchor': 'left', 'y': 1, 'yanchor': 'top'},
#                'margin': {'b': 5, 'l': 15, 'r': 15, 't': 5},
#                'paper_bgcolor': '#FFFFFF',
#                'plot_bgcolor': '#FFFFFF',
#                'shapes': [{'line': {'color': '#00FFFF', 'dash': 'dot', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1105,
#                            'y1': 1105,
#                            'yref': 'y'},
#                           {'fillcolor': 'lightskyblue',
#                            'layer': 'above',
#                            'line': {'color': 'green', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1115,
#                            'y1': 1125,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x7 domain',
#                            'y0': 1080,
#                            'y1': 1090,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.5,
#                            'xref': 'x7 domain',
#                            'y0': 1090,
#                            'y1': 1110,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.7,
#                            'xref': 'x7 domain',
#                            'y0': 1110,
#                            'y1': 1115,
#                            'yref': 'y'},
#                           {'fillcolor': 'goldenrod',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.2,
#                            'xref': 'x7 domain',
#                            'y0': 1115,
#                            'y1': 1155,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x7 domain',
#                            'y0': 1150,
#                            'y1': 1180,
#                            'yref': 'y'},
#                           {'fillcolor': '#FFFFFF',
#                            'line': {'width': 0},
#                            'type': 'rect',
#                            'x0': 0.4150731158605174,
#                            'x1': 0.44881889763779526,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 0.6444444444444444,
#                            'yref': 'paper'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 889,
#                'xaxis': {'domain': [0.0044994375703037125, 0.1732283464566929],
#                          'gridcolor': '#f0f0f0',
#                          'linecolor': '#008000',
#                          'linewidth': 2,
#                          'nticks': 0,
#                          'position': 0.6444444444444444,
#                          'range': [0, 150.0],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'top',
#                          'tickangle': 55,
#                          'tickcolor': '#008000',
#                          'tickfont': {'color': '#008000'},
#                          'ticklen': 6,
#                          'tickmode': 'auto',
#                          'ticks': 'outside',
#                          'tickwidth': 1,
#                          'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'CGR (gAPI)'},
#                          'type': 'linear',
#                          'zeroline': False},
#                'xaxis10': {'domain': [0.6512935883014623, 0.8200224971878515],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#008000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 0.6444444444444444,
#                            'range': [0, 150.0],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#008000',
#                            'tickfont': {'color': '#008000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'GR (gAPI)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis2': {'anchor': 'free',
#                           'domain': [0.0044994375703037125, 0.1732283464566929],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x',
#                           'position': 0.7333333333333334,
#                           'range': [0.0, 40.64],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CALI (cm)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis3': {'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'LLD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis4': {'anchor': 'free',
#                           'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.7333333333333334,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'ILD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis5': {'anchor': 'free',
#                           'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#0000ff',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.8222222222222222,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#0000ff',
#                           'tickfont': {'color': '#0000ff'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#0000ff'}, 'standoff': 0, 'text': 'ILM (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis6': {'anchor': 'free',
#                           'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#808080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.9111111111111111,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#808080',
#                           'tickfont': {'color': '#808080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#808080'}, 'standoff': 0, 'text': 'LLS (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis7': {'domain': [0.4150731158605174, 0.44881889763779526],
#                           'fixedrange': True,
#                           'position': 0.6444444444444444,
#                           'showgrid': False,
#                           'showline': False,
#                           'side': 'top',
#                           'visible': False,
#                           'zeroline': False},
#                'xaxis8': {'domain': [0.46569178852643417, 0.6344206974128234],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [1.95, 2.95],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'RHOB (g/cm^3)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis9': {'anchor': 'free',
#                           'domain': [0.46569178852643417, 0.6344206974128234],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#008080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x8',
#                           'position': 0.7333333333333334,
#                           'range': [45.0, -15.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#008080',
#                           'tickfont': {'color': '#008080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#008080'}, 'standoff': 0, 'text': 'NPHI (pu)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'yaxis': {'domain': [0.011111111111111112, 0.6444444444444444],
#                          'gridcolor': '#f0f0f0',
#                          'maxallowed': np.float64(1832.1528),
#                          'minallowed': np.float64(0.1524),
#                          'position': 0.2249718785151856,
#                          'range': [1180, 1080],
#                          'showgrid': True,
#                          'showline': False,
#                          'visible': True,
#                          'zeroline': False}}
# })

# %%
graph2.get_trace("RHOB").set_theme({"cross_axis_fill": "some name"})
graph2.get_trace("NPHI").set_theme({"cross_axis_fill": ("some name", {}), "fillcolor": "yellow"})
graph2.render(depth_position=0, show_depth=True, depth=[1080, 1180])
# Out:
# xpFigureWidget({
#     'data': [{'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5009fddc-f830-4b0e-a52b-622604c174cb',
#               'x': {'bdata': ('6Ugu/yGjUkCmft5UpIZSQNqPFJFhh1' ... '8LtSZOQECH+fIC8FBAxF+TNeoPU0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CALI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3719af0c-b498-4cab-bc75-9119f1e94b22',
#               'x': {'bdata': ('uK8D54x4KEBsPq4NFXMoQMu5FFeVTS' ... 'NdEyFAOxqH+l0QIUDS5GIMrAshQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('LGUZ4ljjckC94xQdyeVyQE5iEFg56H' ... 'iVUpxA1XjpJjFTnEB5WKg1zVOcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd91a56e6-424a-4d53-bf60-2a2d34489a6e',
#               'x': {'bdata': ('Y/IGmPnO9T8WwmosYS36P11r71NV6P' ... 'XU6gdAxqhr7X3KB0Dg10gShGsHQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'kmkJxAorQ3+MKQnEBGlPYGX5GcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '67c5d270-8f4a-4c8b-8b02-22d8c0ca7432',
#               'x': {'bdata': ('b+ahAJs93T8WmF8XjxzdPx+duvJZHt' ... 'ykOgpAkKD4MeZuCkB+x/DYz0IKQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x4',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... 'kTmJxA+Q/pt6+YnECe76fGS5mcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#0000ff', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILM',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b52223b7-7a8a-4d8b-914c-f69264a83a98',
#               'x': {'bdata': ('iudsAaE14T//DvvzIzThP8/abReaq+' ... 'RyLzDLCUCamC7E6m8JQIXNABdkiwlA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x5',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... '+nxkuZnEBCz2bV55mcQOauJeSDmpxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#808080', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLS',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'dca1ffa1-20f7-4e4a-9c8d-2a4828d49267',
#               'x': {'bdata': ('xr5k48GW8z9bzxCOWXb2PypWDcLc7v' ... 'Mh/2wHQPG9v0F7NQdAdVYL7DHRBkA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x6',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'f4wpCcQEaU9gZfkZxA63O1FfuRnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hoverinfo': 'skip',
#               'mode': 'markers',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '510a538d-98f8-47f9-a1ef-93cc9eabdadd',
#               'x': [0],
#               'xaxis': 'x7',
#               'y': [0],
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'RHOB',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0fc9ba7b-10b9-448e-a954-72019a20a565',
#               'x': {'bdata': ('ebKbGf3o/j8a3xeXqvT6P+3zGOWZV/' ... 'cqPwRAXkvIBz07BEAqjZjZ5zEEQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x8',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'LeZJxAFK5H4XplnEC5jQbwFmacQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'yellow',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008080', 'width': 1},
#               'mode': 'lines',
#               'name': 'NPHI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bfd84077-3ae8-4280-bd9b-c34d7c4a0a2e',
#               'x': {'bdata': ('EAaeew9bQUBIbeLkfmNDQD7t8NdkpU' ... 'ms+uQ0QGFPO/w1GTVAYOXQItuRNUA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fill': 'tonextx',
#               'fillcolor': 'yellow',
#               'line': {'color': 'black', 'width': 0},
#               'mode': 'lines',
#               'name': 'RHOB-shadow',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '702523bd-2eeb-4bb0-a67d-4f4d634ff9a9',
#               'x': {'bdata': ('XBH8byULR0CuPbMkQHVOQFGbOLnfrV' ... 'SITCRAgJVDi2yHJECQug9AahMlQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'GR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5bb7160f-5fe3-418e-8ff3-2db46203b810',
#               'x': {'bdata': ('Q+c1dolyOEBCW86luLI4QDAqqRPQxD' ... 'tRuB7TYkB8YTJVMJhiQFXBqKROCmJA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x10',
#               'y': {'bdata': ('i2zn+6kxPECbVZ+rrVg8QKs+V1uxfz' ... 'JVMCpenEAGEhQ/xl6cQKrx0k1iX5xA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Mardie Greensand',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1105,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Barrow Group',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1115,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1080,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1090,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1110,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1115,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1150,
#                                 'yref': 'y',
#                                 'yshift': -5}],
#                'height': 900,
#                'legend': {'xanchor': 'left', 'y': 1, 'yanchor': 'top'},
#                'margin': {'b': 5, 'l': 15, 'r': 15, 't': 5},
#                'paper_bgcolor': '#FFFFFF',
#                'plot_bgcolor': '#FFFFFF',
#                'shapes': [{'line': {'color': '#00FFFF', 'dash': 'dot', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1105,
#                            'y1': 1105,
#                            'yref': 'y'},
#                           {'fillcolor': 'lightskyblue',
#                            'layer': 'above',
#                            'line': {'color': 'green', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1115,
#                            'y1': 1125,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x7 domain',
#                            'y0': 1080,
#                            'y1': 1090,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.5,
#                            'xref': 'x7 domain',
#                            'y0': 1090,
#                            'y1': 1110,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.7,
#                            'xref': 'x7 domain',
#                            'y0': 1110,
#                            'y1': 1115,
#                            'yref': 'y'},
#                           {'fillcolor': 'goldenrod',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.2,
#                            'xref': 'x7 domain',
#                            'y0': 1115,
#                            'y1': 1155,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x7 domain',
#                            'y0': 1150,
#                            'y1': 1180,
#                            'yref': 'y'},
#                           {'fillcolor': '#FFFFFF',
#                            'line': {'width': 0},
#                            'type': 'rect',
#                            'x0': 0.3911007025761124,
#                            'x1': 0.4262295081967213,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 0.6444444444444444,
#                            'yref': 'paper'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 854,
#                'xaxis': {'domain': [0.00468384074941452, 0.18032786885245902],
#                          'gridcolor': '#f0f0f0',
#                          'linecolor': '#008000',
#                          'linewidth': 2,
#                          'nticks': 0,
#                          'position': 0.6444444444444444,
#                          'range': [0, 150.0],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'top',
#                          'tickangle': 55,
#                          'tickcolor': '#008000',
#                          'tickfont': {'color': '#008000'},
#                          'ticklen': 6,
#                          'tickmode': 'auto',
#                          'ticks': 'outside',
#                          'tickwidth': 1,
#                          'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'CGR (gAPI)'},
#                          'type': 'linear',
#                          'zeroline': False},
#                'xaxis10': {'domain': [0.6370023419203747, 0.8126463700234192],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#008000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 0.6444444444444444,
#                            'range': [0, 150.0],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#008000',
#                            'tickfont': {'color': '#008000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'GR (gAPI)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis2': {'anchor': 'free',
#                           'domain': [0.00468384074941452, 0.18032786885245902],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x',
#                           'position': 0.7333333333333334,
#                           'range': [0.0, 40.64],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CALI (cm)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis3': {'domain': [0.19789227166276346, 0.373536299765808],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'LLD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis4': {'anchor': 'free',
#                           'domain': [0.19789227166276346, 0.373536299765808],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.7333333333333334,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'ILD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis5': {'anchor': 'free',
#                           'domain': [0.19789227166276346, 0.373536299765808],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#0000ff',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.8222222222222222,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#0000ff',
#                           'tickfont': {'color': '#0000ff'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#0000ff'}, 'standoff': 0, 'text': 'ILM (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis6': {'anchor': 'free',
#                           'domain': [0.19789227166276346, 0.373536299765808],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#808080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.9111111111111111,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#808080',
#                           'tickfont': {'color': '#808080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#808080'}, 'standoff': 0, 'text': 'LLS (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis7': {'domain': [0.3911007025761124, 0.4262295081967213],
#                           'fixedrange': True,
#                           'position': 0.6444444444444444,
#                           'showgrid': False,
#                           'showline': False,
#                           'side': 'top',
#                           'visible': False,
#                           'zeroline': False},
#                'xaxis8': {'domain': [0.44379391100702575, 0.6194379391100703],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [1.95, 2.95],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'RHOB (g/cm^3)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis9': {'anchor': 'free',
#                           'domain': [0.44379391100702575, 0.6194379391100703],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#008080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x8',
#                           'position': 0.7333333333333334,
#                           'range': [45.0, -15.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#008080',
#                           'tickfont': {'color': '#008080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#008080'}, 'standoff': 0, 'text': 'NPHI (pu)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'yaxis': {'domain': [0.011111111111111112, 0.6444444444444444],
#                          'gridcolor': '#f0f0f0',
#                          'maxallowed': np.float64(1832.1528),
#                          'minallowed': np.float64(0.1524),
#                          'position': 0,
#                          'range': [1180, 1080],
#                          'showgrid': True,
#                          'showline': False,
#                          'visible': True,
#                          'zeroline': False}}
# })

# %%
graph2.get_trace("CGR").set_theme({"fill": 'heatmap'})
graph2.render(depth_position=1, show_depth=True, depth=[1080, 1180])
# Out:
# xpFigureWidget({
#     'data': [{'fill': 'tozerox',
#               'fillcolor': 'white',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '83407141-3eb2-4716-bdf1-1f6418d9a69d',
#               'x': {'bdata': ('6Ugu/yGjUkCmft5UpIZSQNqPFJFhh1' ... '8LtSZOQECH+fIC8FBAxF+TNeoPU0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hoverinfo': 'skip',
#               'showlegend': False,
#               'showscale': False,
#               'type': 'heatmap',
#               'uid': 'fe93b101-6826-409c-aa1d-ca36deee2c30',
#               'x': [268.2714, 35.49274],
#               'xaxis': 'x',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y',
#               'z': [[74.54895], [74.10378], [74.11533], ..., [60.3024],
#                     [67.75018], [76.24867]]},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CALI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6f45dd6c-f252-4c4e-8bfe-fec10e6063aa',
#               'x': {'bdata': ('uK8D54x4KEBsPq4NFXMoQMu5FFeVTS' ... 'NdEyFAOxqH+l0QIUDS5GIMrAshQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('LGUZ4ljjckC94xQdyeVyQE5iEFg56H' ... 'iVUpxA1XjpJjFTnEB5WKg1zVOcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4a7aa4c5-1b31-45f2-8b47-72306dd1c82d',
#               'x': {'bdata': ('Y/IGmPnO9T8WwmosYS36P11r71NV6P' ... 'XU6gdAxqhr7X3KB0Dg10gShGsHQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'kmkJxAorQ3+MKQnEBGlPYGX5GcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '11e88c5e-8bd5-48fb-8367-dce6bc54b656',
#               'x': {'bdata': ('b+ahAJs93T8WmF8XjxzdPx+duvJZHt' ... 'ykOgpAkKD4MeZuCkB+x/DYz0IKQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x4',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... 'kTmJxA+Q/pt6+YnECe76fGS5mcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#0000ff', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILM',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'cda97d49-b549-4653-8837-2e947d0723b1',
#               'x': {'bdata': ('iudsAaE14T//DvvzIzThP8/abReaq+' ... 'RyLzDLCUCamC7E6m8JQIXNABdkiwlA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x5',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... '+nxkuZnEBCz2bV55mcQOauJeSDmpxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#808080', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLS',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1cd74495-198f-4138-a3b6-f73d57dcce64',
#               'x': {'bdata': ('xr5k48GW8z9bzxCOWXb2PypWDcLc7v' ... 'Mh/2wHQPG9v0F7NQdAdVYL7DHRBkA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x6',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'f4wpCcQEaU9gZfkZxA63O1FfuRnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hoverinfo': 'skip',
#               'mode': 'markers',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '38f740ef-8b5e-4176-b29a-57f8e5471a25',
#               'x': [0],
#               'xaxis': 'x7',
#               'y': [0],
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'RHOB',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'af0c4bd8-00b4-4bda-b455-cc72e043c3db',
#               'x': {'bdata': ('ebKbGf3o/j8a3xeXqvT6P+3zGOWZV/' ... 'cqPwRAXkvIBz07BEAqjZjZ5zEEQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x8',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'LeZJxAFK5H4XplnEC5jQbwFmacQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'yellow',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008080', 'width': 1},
#               'mode': 'lines',
#               'name': 'NPHI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd75cb947-b38c-437c-b69c-e1906ae5d95c',
#               'x': {'bdata': ('EAaeew9bQUBIbeLkfmNDQD7t8NdkpU' ... 'ms+uQ0QGFPO/w1GTVAYOXQItuRNUA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fill': 'tonextx',
#               'fillcolor': 'yellow',
#               'line': {'color': 'black', 'width': 0},
#               'mode': 'lines',
#               'name': 'RHOB-shadow',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'af6bf957-04df-4b6d-b5f5-eae452911ff9',
#               'x': {'bdata': ('XBH8byULR0CuPbMkQHVOQFGbOLnfrV' ... 'SITCRAgJVDi2yHJECQug9AahMlQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'GR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2775f315-78c6-46a6-a4fd-18e96dd35cd3',
#               'x': {'bdata': ('Q+c1dolyOEBCW86luLI4QDAqqRPQxD' ... 'tRuB7TYkB8YTJVMJhiQFXBqKROCmJA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x10',
#               'y': {'bdata': ('i2zn+6kxPECbVZ+rrVg8QKs+V1uxfz' ... 'JVMCpenEAGEhQ/xl6cQKrx0k1iX5xA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Mardie Greensand',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1105,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': 'Barrow Group',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1115,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1080,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1090,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1110,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1115,
#                                 'yref': 'y',
#                                 'yshift': -5},
#                                {'axref': 'x7 domain',
#                                 'ayref': 'y',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x7 domain',
#                                 'y': 1150,
#                                 'yref': 'y',
#                                 'yshift': -5}],
#                'height': 900,
#                'legend': {'xanchor': 'left', 'y': 1, 'yanchor': 'top'},
#                'margin': {'b': 5, 'l': 15, 'r': 15, 't': 5},
#                'paper_bgcolor': '#FFFFFF',
#                'plot_bgcolor': '#FFFFFF',
#                'shapes': [{'line': {'color': '#00FFFF', 'dash': 'dot', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1105,
#                            'y1': 1105,
#                            'yref': 'y'},
#                           {'fillcolor': 'lightskyblue',
#                            'layer': 'above',
#                            'line': {'color': 'green', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1115,
#                            'y1': 1125,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x7 domain',
#                            'y0': 1080,
#                            'y1': 1090,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.5,
#                            'xref': 'x7 domain',
#                            'y0': 1090,
#                            'y1': 1110,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.7,
#                            'xref': 'x7 domain',
#                            'y0': 1110,
#                            'y1': 1115,
#                            'yref': 'y'},
#                           {'fillcolor': 'goldenrod',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.2,
#                            'xref': 'x7 domain',
#                            'y0': 1115,
#                            'y1': 1155,
#                            'yref': 'y'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x7 domain',
#                            'y0': 1150,
#                            'y1': 1180,
#                            'yref': 'y'},
#                           {'fillcolor': '#FFFFFF',
#                            'line': {'width': 0},
#                            'type': 'rect',
#                            'x0': 0.4150731158605174,
#                            'x1': 0.44881889763779526,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 0.6444444444444444,
#                            'yref': 'paper'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 889,
#                'xaxis': {'domain': [0.0044994375703037125, 0.1732283464566929],
#                          'gridcolor': '#f0f0f0',
#                          'linecolor': '#008000',
#                          'linewidth': 2,
#                          'nticks': 0,
#                          'position': 0.6444444444444444,
#                          'range': [0, 150.0],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'top',
#                          'tickangle': 55,
#                          'tickcolor': '#008000',
#                          'tickfont': {'color': '#008000'},
#                          'ticklen': 6,
#                          'tickmode': 'auto',
#                          'ticks': 'outside',
#                          'tickwidth': 1,
#                          'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'CGR (gAPI)'},
#                          'type': 'linear',
#                          'zeroline': False},
#                'xaxis10': {'domain': [0.6512935883014623, 0.8200224971878515],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#008000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 0.6444444444444444,
#                            'range': [0, 150.0],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#008000',
#                            'tickfont': {'color': '#008000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'GR (gAPI)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis2': {'anchor': 'free',
#                           'domain': [0.0044994375703037125, 0.1732283464566929],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x',
#                           'position': 0.7333333333333334,
#                           'range': [0.0, 40.64],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CALI (cm)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis3': {'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'LLD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis4': {'anchor': 'free',
#                           'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.7333333333333334,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'ILD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis5': {'anchor': 'free',
#                           'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#0000ff',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.8222222222222222,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#0000ff',
#                           'tickfont': {'color': '#0000ff'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#0000ff'}, 'standoff': 0, 'text': 'ILM (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis6': {'anchor': 'free',
#                           'domain': [0.22947131608548932, 0.3982002249718785],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#808080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x3',
#                           'position': 0.9111111111111111,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#808080',
#                           'tickfont': {'color': '#808080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#808080'}, 'standoff': 0, 'text': 'LLS (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis7': {'domain': [0.4150731158605174, 0.44881889763779526],
#                           'fixedrange': True,
#                           'position': 0.6444444444444444,
#                           'showgrid': False,
#                           'showline': False,
#                           'side': 'top',
#                           'visible': False,
#                           'zeroline': False},
#                'xaxis8': {'domain': [0.46569178852643417, 0.6344206974128234],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6444444444444444,
#                           'range': [1.95, 2.95],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'RHOB (g/cm^3)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis9': {'anchor': 'free',
#                           'domain': [0.46569178852643417, 0.6344206974128234],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#008080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x8',
#                           'position': 0.7333333333333334,
#                           'range': [45.0, -15.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#008080',
#                           'tickfont': {'color': '#008080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#008080'}, 'standoff': 0, 'text': 'NPHI (pu)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'yaxis': {'domain': [0.011111111111111112, 0.6444444444444444],
#                          'gridcolor': '#f0f0f0',
#                          'maxallowed': np.float64(1832.1528),
#                          'minallowed': np.float64(0.1524),
#                          'position': 0.2249718785151856,
#                          'range': [1180, 1080],
#                          'showgrid': True,
#                          'showline': False,
#                          'visible': True,
#                          'zeroline': False}}
# })

# %% [markdown]
# ### Step 4: Make a crossplot

# %%
graph2.CrossPlot(
    x = graph2.get_trace("NPHI"),
    y = graph2.get_trace("RHOB"),
    colors = ["depth"],
    xrange=(45, -15),
    yrange=(1.95, 2.945),
    size=800,
    depth_range=(1100, 1300),
).render()
# Out:
# xpFigureWidget({
#     'data': [{'hovertemplate': '%{x}, %{y}, %{marker.color}',
#               'marker': {'color': {'bdata': ('EqW9wRcwkUC2hHzQszCRQFpkO99PMZ' ... 'snD06UQJEPejarTpRANe84RUdPlEA='),
#                                    'dtype': 'f8'},
#                          'colorbar': {'orientation': 'h',
#                                       'thickness': 20,
#                                       'thicknessmode': 'pixels',
#                                       'title': {'text': 'depth'}},
#                          'colorscale': [[0.0, '#fde725'], [0.1111111111111111,
#                                         '#b5de2b'], [0.2222222222222222,
#                                         '#6ece58'], [0.3333333333333333,
#                                         '#35b779'], [0.4444444444444444,
#                                         '#1f9e89'], [0.5555555555555556,
#                                         '#26828e'], [0.6666666666666666,
#                                         '#31688e'], [0.7777777777777778,
#                                         '#3e4989'], [0.8888888888888888,
#                                         '#482878'], [1.0, '#440154']],
#                          'opacity': 1,
#                          'showscale': True,
#                          'size': 5,
#                          'symbol': 'circle'},
#               'meta': {'color_data': 'depth', 'filter': 'depth'},
#               'mode': 'markers',
#               'name': 'depth',
#               'type': 'scattergl',
#               'uid': '1ae92559-8bc7-4764-8e3b-9b9950511d5e',
#               'x': {'bdata': ('w9hCkINiRUDGhQMhWZRFQFt8CoDxqE' ... 'PaUNE6QItPATCe4TpANsgkI2exO0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('CyqqfqWz+T8yObUzTO39P3Y3T3XILQ' ... 'MeZzoEQML2kzE+bARAVHB4QUQqBEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'height': 800,
#                'showlegend': True,
#                'template': '...',
#                'width': 800,
#                'xaxis': {'linecolor': '#888', 'linewidth': 1, 'range': [45, -15], 'title': {'text': 'NPHI'}},
#                'yaxis': {'domain': [0, 1],
#                          'linecolor': '#888',
#                          'linewidth': 1,
#                          'range': [1.95, 2.945],
#                          'title': {'text': 'RHOB'}}}
# })

# %% [markdown]
# ### Step 5: Make an interactive crossplot

# %%
graph2.render(height=800, depth_position=1, xp=graph2.xp, depth=[1100, 1300],)
# Out:
# xpFigureWidget({
#     'data': [{'fill': 'tozerox',
#               'fillcolor': 'white',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1a6b6ed3-045e-4aa1-bcc5-101a047d9ca2',
#               'x': {'bdata': ('6Ugu/yGjUkCmft5UpIZSQNqPFJFhh1' ... '8LtSZOQECH+fIC8FBAxF+TNeoPU0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'hoverinfo': 'skip',
#               'showlegend': False,
#               'showscale': False,
#               'type': 'heatmap',
#               'uid': 'dc93fa57-b699-4d3f-bfc9-a8c20b9da6d2',
#               'x': [268.2714, 35.49274],
#               'xaxis': 'x2',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2',
#               'z': [[74.54895], [74.10378], [74.11533], ..., [60.3024],
#                     [67.75018], [76.24867]]},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CALI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '55fa8902-5906-439a-972d-ea1d2081330d',
#               'x': {'bdata': ('uK8D54x4KEBsPq4NFXMoQMu5FFeVTS' ... 'NdEyFAOxqH+l0QIUDS5GIMrAshQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('LGUZ4ljjckC94xQdyeVyQE5iEFg56H' ... 'iVUpxA1XjpJjFTnEB5WKg1zVOcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0ad5b82a-fb8f-46b3-afe8-8981ecb4e91b',
#               'x': {'bdata': ('Y/IGmPnO9T8WwmosYS36P11r71NV6P' ... 'XU6gdAxqhr7X3KB0Dg10gShGsHQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x4',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'kmkJxAorQ3+MKQnEBGlPYGX5GcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILD',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ca0abad0-6dba-46e6-bd72-4e8f8b2d3c9d',
#               'x': {'bdata': ('b+ahAJs93T8WmF8XjxzdPx+duvJZHt' ... 'ykOgpAkKD4MeZuCkB+x/DYz0IKQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x5',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... 'kTmJxA+Q/pt6+YnECe76fGS5mcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#0000ff', 'width': 1},
#               'mode': 'lines',
#               'name': 'ILM',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0ae19b6c-726b-4eb4-b735-8b7b0e945767',
#               'x': {'bdata': ('iudsAaE14T//DvvzIzThP8/abReaq+' ... 'RyLzDLCUCamC7E6m8JQIXNABdkiwlA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x6',
#               'y': {'bdata': ('m+Ydp+jgckAsZRniWONyQL3jFB3J5X' ... '+nxkuZnEBCz2bV55mcQOauJeSDmpxA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#808080', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLS',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '58b19f6a-99ad-432f-af54-597a7b8aef7a',
#               'x': {'bdata': ('xr5k48GW8z9bzxCOWXb2PypWDcLc7v' ... 'Mh/2wHQPG9v0F7NQdAdVYL7DHRBkA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x7',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'f4wpCcQEaU9gZfkZxA63O1FfuRnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'hoverinfo': 'skip',
#               'mode': 'markers',
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd7224b69-a2ef-4280-9ce0-68bbab70a66f',
#               'x': [0],
#               'xaxis': 'x8',
#               'y': [0],
#               'yaxis': 'y2'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#ff0000', 'width': 1},
#               'mode': 'lines',
#               'name': 'RHOB',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd0a238a4-f54a-4a7b-8050-da949c147d3a',
#               'x': {'bdata': ('ebKbGf3o/j8a3xeXqvT6P+3zGOWZV/' ... 'cqPwRAXkvIBz07BEAqjZjZ5zEEQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x9',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'LeZJxAFK5H4XplnEC5jQbwFmacQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'fillcolor': 'yellow',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008080', 'width': 1},
#               'mode': 'lines',
#               'name': 'NPHI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '08d41f11-28b1-4418-ba32-285e0b6da596',
#               'x': {'bdata': ('EAaeew9bQUBIbeLkfmNDQD7t8NdkpU' ... 'ms+uQ0QGFPO/w1GTVAYOXQItuRNUA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x10',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'fill': 'tonextx',
#               'fillcolor': 'yellow',
#               'line': {'color': 'black', 'width': 0},
#               'mode': 'lines',
#               'name': 'RHOB-shadow',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '85e4545f-736b-4fac-8dca-42aa88268b7c',
#               'x': {'bdata': ('XBH8byULR0CuPbMkQHVOQFGbOLnfrV' ... 'SITCRAgJVDi2yHJECQug9AahMlQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x10',
#               'y': {'bdata': ('yJi7lpAOkUBseHqlLA+RQBBYObTID5' ... 'RhoVWcQArXo3A9VpxArrZif9lWnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'GR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3d8e3a91-69a0-4b7f-a8a4-9d3c64673d2b',
#               'x': {'bdata': ('Q+c1dolyOEBCW86luLI4QDAqqRPQxD' ... 'tRuB7TYkB8YTJVMJhiQFXBqKROCmJA'),
#                     'dtype': 'f8'},
#               'xaxis': 'x11',
#               'y': {'bdata': ('i2zn+6kxPECbVZ+rrVg8QKs+V1uxfz' ... 'JVMCpenEAGEhQ/xl6cQKrx0k1iX5xA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'hovertemplate': '%{x}, %{y}, %{marker.color}',
#               'marker': {'color': {'bdata': ('EqW9wRcwkUC2hHzQszCRQFpkO99PMZ' ... 'snD06UQJEPejarTpRANe84RUdPlEA='),
#                                    'dtype': 'f8'},
#                          'colorbar': {'len': 720.0,
#                                       'lenmode': 'pixels',
#                                       'orientation': 'h',
#                                       'thickness': 20,
#                                       'thicknessmode': 'pixels',
#                                       'title': {'text': 'depth'},
#                                       'x': 0.21018354055654234,
#                                       'xref': 'paper',
#                                       'y': 0.0125,
#                                       'yref': 'paper'},
#                          'colorscale': [[0.0, '#fde725'], [0.1111111111111111,
#                                         '#b5de2b'], [0.2222222222222222,
#                                         '#6ece58'], [0.3333333333333333,
#                                         '#35b779'], [0.4444444444444444,
#                                         '#1f9e89'], [0.5555555555555556,
#                                         '#26828e'], [0.6666666666666666,
#                                         '#31688e'], [0.7777777777777778,
#                                         '#3e4989'], [0.8888888888888888,
#                                         '#482878'], [1.0, '#440154']],
#                          'opacity': 1,
#                          'showscale': True,
#                          'size': 5,
#                          'symbol': 'circle'},
#               'meta': {'color_data': 'depth', 'filter': 'depth'},
#               'mode': 'markers',
#               'name': 'depth',
#               'type': 'scattergl',
#               'uid': '313eab84-a100-4d85-9696-6d06a2ed80ee',
#               'x': {'bdata': ('w9hCkINiRUDGhQMhWZRFQFt8CoDxqE' ... 'PaUNE6QItPATCe4TpANsgkI2exO0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('CyqqfqWz+T8yObUzTO39P3Y3T3XILQ' ... 'MeZzoEQML2kzE+bARAVHB4QUQqBEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'ayref': 'y2',
#                                 'showarrow': False,
#                                 'text': 'Mardie Greensand',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1105,
#                                 'yref': 'y2',
#                                 'yshift': -5},
#                                {'ayref': 'y2',
#                                 'showarrow': False,
#                                 'text': 'Barrow Group',
#                                 'x': 1,
#                                 'xref': 'paper',
#                                 'y': 1115,
#                                 'yref': 'y2',
#                                 'yshift': -5},
#                                {'axref': 'x8 domain',
#                                 'ayref': 'y2',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x8 domain',
#                                 'y': 1080,
#                                 'yref': 'y2',
#                                 'yshift': -5},
#                                {'axref': 'x8 domain',
#                                 'ayref': 'y2',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x8 domain',
#                                 'y': 1090,
#                                 'yref': 'y2',
#                                 'yshift': -5},
#                                {'axref': 'x8 domain',
#                                 'ayref': 'y2',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x8 domain',
#                                 'y': 1110,
#                                 'yref': 'y2',
#                                 'yshift': -5},
#                                {'axref': 'x8 domain',
#                                 'ayref': 'y2',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x8 domain',
#                                 'y': 1115,
#                                 'yref': 'y2',
#                                 'yshift': -5},
#                                {'axref': 'x8 domain',
#                                 'ayref': 'y2',
#                                 'showarrow': False,
#                                 'text': '',
#                                 'x': 1,
#                                 'xref': 'x8 domain',
#                                 'y': 1150,
#                                 'yref': 'y2',
#                                 'yshift': -5}],
#                'height': 800,
#                'legend': {'x': 0.37892243931320313, 'xanchor': 'left', 'y': 1, 'yanchor': 'top'},
#                'margin': {'b': 5, 'l': 15, 'r': 15, 't': 5},
#                'paper_bgcolor': '#FFFFFF',
#                'plot_bgcolor': '#FFFFFF',
#                'shapes': [{'line': {'color': '#00FFFF', 'dash': 'dot', 'width': 1},
#                            'type': 'line',
#                            'x0': 0.47365304914150386,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1105,
#                            'y1': 1105,
#                            'yref': 'y2'},
#                           {'fillcolor': 'lightskyblue',
#                            'layer': 'above',
#                            'line': {'color': 'green', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0.47365304914150386,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1115,
#                            'y1': 1125,
#                            'yref': 'y2'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x8 domain',
#                            'y0': 1080,
#                            'y1': 1090,
#                            'yref': 'y2'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.5,
#                            'xref': 'x8 domain',
#                            'y0': 1090,
#                            'y1': 1110,
#                            'yref': 'y2'},
#                           {'fillcolor': 'darkslateblue',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.7,
#                            'xref': 'x8 domain',
#                            'y0': 1110,
#                            'y1': 1115,
#                            'yref': 'y2'},
#                           {'fillcolor': 'goldenrod',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.2,
#                            'xref': 'x8 domain',
#                            'y0': 1115,
#                            'y1': 1155,
#                            'yref': 'y2'},
#                           {'fillcolor': 'darkseagreen',
#                            'layer': 'above',
#                            'line': {'color': 'black', 'dash': 'dot', 'width': 0},
#                            'opacity': 0.5,
#                            'type': 'rect',
#                            'x0': 0,
#                            'x1': 0.4,
#                            'xref': 'x8 domain',
#                            'y0': 1150,
#                            'y1': 1180,
#                            'yref': 'y2'},
#                           {'fillcolor': '#FFFFFF',
#                            'line': {'width': 0},
#                            'type': 'rect',
#                            'x0': 0.6921255180580225,
#                            'x1': 0.7098875074008288,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 0.6,
#                            'yref': 'paper'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 1689,
#                'xaxis': {'domain': [0, 0.47365304914150386],
#                          'linecolor': '#888',
#                          'linewidth': 1,
#                          'range': [45, -15],
#                          'title': {'text': 'NPHI'}},
#                'xaxis10': {'anchor': 'free',
#                            'domain': [0.7187685020722321, 0.8075784487862641],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#008080',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'overlaying': 'x9',
#                            'position': 0.7,
#                            'range': [45.0, -15.0],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#008080',
#                            'tickfont': {'color': '#008080'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#008080'}, 'standoff': 0, 'text': 'NPHI (pu)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis11': {'domain': [0.8164594434576673, 0.9052693901716993],
#                            'gridcolor': '#f0f0f0',
#                            'linecolor': '#008000',
#                            'linewidth': 2,
#                            'nticks': 0,
#                            'position': 0.6,
#                            'range': [0, 150.0],
#                            'showgrid': False,
#                            'showline': True,
#                            'side': 'top',
#                            'tickangle': 55,
#                            'tickcolor': '#008000',
#                            'tickfont': {'color': '#008000'},
#                            'ticklen': 6,
#                            'tickmode': 'auto',
#                            'ticks': 'outside',
#                            'tickwidth': 1,
#                            'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'GR (gAPI)'},
#                            'type': 'linear',
#                            'zeroline': False},
#                'xaxis2': {'domain': [0.47602131438721135, 0.5648312611012434],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#008000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6,
#                           'range': [0, 150.0],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#008000',
#                           'tickfont': {'color': '#008000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'CGR (gAPI)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis3': {'anchor': 'free',
#                           'domain': [0.47602131438721135, 0.5648312611012434],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x2',
#                           'position': 0.7,
#                           'range': [0.0, 40.64],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CALI (cm)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis4': {'domain': [0.5944345766725874, 0.6832445233866193],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'LLD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis5': {'anchor': 'free',
#                           'domain': [0.5944345766725874, 0.6832445233866193],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x4',
#                           'position': 0.7,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'ILD (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis6': {'anchor': 'free',
#                           'domain': [0.5944345766725874, 0.6832445233866193],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#0000ff',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x4',
#                           'position': 0.8,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#0000ff',
#                           'tickfont': {'color': '#0000ff'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#0000ff'}, 'standoff': 0, 'text': 'ILM (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis7': {'anchor': 'free',
#                           'domain': [0.5944345766725874, 0.6832445233866193],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#808080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x4',
#                           'position': 0.9,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#808080',
#                           'tickfont': {'color': '#808080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#808080'}, 'standoff': 0, 'text': 'LLS (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'xaxis8': {'domain': [0.6921255180580225, 0.7098875074008288],
#                           'fixedrange': True,
#                           'position': 0.6,
#                           'showgrid': False,
#                           'showline': False,
#                           'side': 'top',
#                           'visible': False,
#                           'zeroline': False},
#                'xaxis9': {'domain': [0.7187685020722321, 0.8075784487862641],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#ff0000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.6,
#                           'range': [1.95, 2.95],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#ff0000',
#                           'tickfont': {'color': '#ff0000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#ff0000'}, 'standoff': 0, 'text': 'RHOB (g/cm^3)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'yaxis': {'domain': [0.15, 1],
#                          'linecolor': '#888',
#                          'linewidth': 1,
#                          'range': [1.95, 2.945],
#                          'title': {'text': 'RHOB'}},
#                'yaxis2': {'domain': [0.0125, 0.6],
#                           'gridcolor': '#f0f0f0',
#                           'maxallowed': np.float64(1832.1528),
#                           'minallowed': np.float64(0.1524),
#                           'position': 0.5920663114268798,
#                           'range': [1300, 1100],
#                           'showgrid': True,
#                           'showline': False,
#                           'visible': True,
#                           'zeroline': False}}
# })

# %%
#pozo.renderers.plotly.make_xp_depth_video(folder_name = "frames",
#                                 graph = graph2,
#                                 window = 25,
#                                 start = 1100,
#                                 end = 1200,)

# VERY MEMORY HUNGRY, improved in incoming kaleido v1.0.0
# see included video

# %% [markdown]
# # Incoming Features For Pozo
#
# * strip log editing and importing like spreadsheet and from agilescience/striplog
# * better declarations
# * fills
# * extensive documentations

# %%
declaration = [
    { # Track 1
        "GR": {
            "mnemonics": ["CGR", "GR", "SGR"],
            "optional": False,
        },
        "CALI": {
            "mnemonics": ["CALI"],
            "optional": True,
        },
    },
    { # Track 2
        "LLS": {
            "mnemonics": ["LLS"],
            "optional": False,
            }
    }
]
graph_declarative = pozo.Graph(las, declare=declaration)
graph_declarative.set_theme("cangrejo")
graph_declarative.render(depth=[1000, 1200])
# Out:
# xpFigureWidget({
#     'data': [{'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#008000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CGR',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd32fcdeb-0fe6-4eb8-8ea8-0dd08555e06d',
#               'x': {'bdata': ('6Ugu/yGjUkCmft5UpIZSQNqPFJFhh1' ... '8LtSZOQECH+fIC8FBAxF+TNeoPU0A='),
#                     'dtype': 'f8'},
#               'xaxis': 'x',
#               'y': {'bdata': ('oImw4enxkEBEaW/whfKQQOlILv8h85' ... 'fRAI6SQP32deCcjpJAodY07ziPkkA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#000000', 'width': 1},
#               'mode': 'lines',
#               'name': 'CALI',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '444ceb93-13c0-484f-9c6b-f6b2fd697cfc',
#               'x': {'bdata': ('uK8D54x4KEBsPq4NFXMoQMu5FFeVTS' ... 'NdEyFAOxqH+l0QIUDS5GIMrAshQA=='),
#                     'dtype': 'f8'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('LGUZ4ljjckC94xQdyeVyQE5iEFg56H' ... 'iVUpxA1XjpJjFTnEB5WKg1zVOcQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'fillcolor': 'blue',
#               'hovertemplate': 'Depth: %{y}, Value: %{x}',
#               'line': {'color': '#808080', 'width': 1},
#               'mode': 'lines',
#               'name': 'LLS',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b1527ba5-682f-426a-b0a3-6d1be5fe2714',
#               'x': {'bdata': ('xr5k48GW8z9bzxCOWXb2PypWDcLc7v' ... 'Mh/2wHQPG9v0F7NQdAdVYL7DHRBkA='),
#                     'dtype': 'f8'},
#               'xaxis': 'x3',
#               'y': {'bdata': ('WRe30QARkUD99nXgnBGRQKHWNO84Ep' ... 'f4wpCcQEaU9gZfkZxA63O1FfuRnEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'height': 900,
#                'legend': {'xanchor': 'left', 'y': 1, 'yanchor': 'top'},
#                'margin': {'b': 5, 'l': 15, 'r': 15, 't': 5},
#                'paper_bgcolor': '#FFFFFF',
#                'plot_bgcolor': '#FFFFFF',
#                'showlegend': True,
#                'template': '...',
#                'width': 319,
#                'xaxis': {'domain': [0.012539184952978056, 0.4827586206896552],
#                          'gridcolor': '#f0f0f0',
#                          'linecolor': '#008000',
#                          'linewidth': 2,
#                          'nticks': 0,
#                          'position': 0.8222222222222222,
#                          'range': [0, 150.0],
#                          'showgrid': False,
#                          'showline': True,
#                          'side': 'top',
#                          'tickangle': 55,
#                          'tickcolor': '#008000',
#                          'tickfont': {'color': '#008000'},
#                          'ticklen': 6,
#                          'tickmode': 'auto',
#                          'ticks': 'outside',
#                          'tickwidth': 1,
#                          'title': {'font': {'color': '#008000'}, 'standoff': 0, 'text': 'GR (gAPI)'},
#                          'type': 'linear',
#                          'zeroline': False},
#                'xaxis2': {'anchor': 'free',
#                           'domain': [0.012539184952978056, 0.4827586206896552],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#000000',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'overlaying': 'x',
#                           'position': 0.9111111111111111,
#                           'range': [0.0, 40.64],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#000000',
#                           'tickfont': {'color': '#000000'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#000000'}, 'standoff': 0, 'text': 'CALI (cm)'},
#                           'type': 'linear',
#                           'zeroline': False},
#                'xaxis3': {'domain': [0.5297805642633229, 1.0],
#                           'gridcolor': '#f0f0f0',
#                           'linecolor': '#808080',
#                           'linewidth': 2,
#                           'nticks': 0,
#                           'position': 0.8222222222222222,
#                           'range': [-0.6989700043360187, 3.301029995663981],
#                           'showgrid': False,
#                           'showline': True,
#                           'side': 'top',
#                           'tickangle': 55,
#                           'tickcolor': '#808080',
#                           'tickfont': {'color': '#808080'},
#                           'ticklen': 6,
#                           'tickmode': 'auto',
#                           'ticks': 'outside',
#                           'tickwidth': 1,
#                           'title': {'font': {'color': '#808080'}, 'standoff': 0, 'text': 'LLS (m*Ω)'},
#                           'type': 'log',
#                           'zeroline': False},
#                'yaxis': {'domain': [0.011111111111111112, 0.8222222222222222],
#                          'gridcolor': '#f0f0f0',
#                          'maxallowed': np.float64(1832.1528),
#                          'minallowed': np.float64(0.1524),
#                          'position': 0,
#                          'range': [1200, 1000],
#                          'showgrid': True,
#                          'showline': False,
#                          'visible': True,
#                          'zeroline': False}}
# })
